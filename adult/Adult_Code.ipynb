# %% [markdown]
# 一、資料讀取與套件載入

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense

# %%
train_data=pd.read_csv("Adult_FinalTrain.csv")
train_data
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       39          5   77516          9             13               4
# 1       50          4   83311          9             13               2
# 2       38          2  215646         11              9               0
# 3       53          2  234721          1              7               2
# 4       28          2  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 30157   27          2  257302          7             12               2
# 30158   40          2  154374         11              9               2
# 30159   58          2  151910         11              9               6
# 30160   22          2  201490         11              9               4
# 30161   52          3  287927         11              9               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0               0             1     4    1          2174             0
# 1               3             0     4    1             0             0
# 2               5             1     4    1             0             0
# 3               5             0     2    1             0             0
# 4               9             5     2    0             0             0
# ...           ...           ...   ...  ...           ...           ...
# 30157          12             5     4    0             0             0
# 30158           6             0     4    1             0             0
# 30159           0             4     4    0             0             0
# 30160           0             3     4    1             0             0
# 30161           3             5     4    0         15024             0
#
#        hours-per-week  native-country  salary
# 0                  40              38       0
# 1                  13              38       0
# 2                  40              38       0
# 3                  40              38       0
# 4                  40               4       0
# ...               ...             ...     ...
# 30157              38              38       0
# 30158              40              38       1
# 30159              40              38       0
# 30160              20              38       0
# 30161              40              38       1
#
# [30162 rows x 15 columns]

# %%
test_data=pd.read_csv("Adult_FinalTest.csv")
test_data
# Out:
#        age  workclass  fnlwgt  education  education-num  marital-status  \
# 0       25          2  226802          1              7               4
# 1       38          2   89814         11              9               2
# 2       28          1  336951          7             12               2
# 3       44          2  160323         15             10               2
# 4       34          2  198693          0              6               4
# ...    ...        ...     ...        ...            ...             ...
# 15055   33          2  245211          9             13               4
# 15056   39          2  215419          9             13               0
# 15057   38          2  374983          9             13               2
# 15058   44          2   83891          9             13               0
# 15059   35          3  182148          9             13               2
#
#        occupation  relationship  race  sex  capital-gain  capital-loss  \
# 0               6             3     2    1             0             0
# 1               4             0     4    1             0             0
# 2              10             0     4    1             0             0
# 3               6             0     2    1          7688             0
# 4               7             1     4    1             0             0
# ...           ...           ...   ...  ...           ...           ...
# 15055           9             3     4    1             0             0
# 15056           9             1     4    0             0             0
# 15057           9             0     4    1             0             0
# 15058           0             3     1    1          5455             0
# 15059           3             0     4    1             0             0
#
#        hours-per-week  native-country  salary
# 0                  40              37       0
# 1                  50              37       0
# 2                  40              37       1
# 3                  40              37       1
# 4                  30              37       0
# ...               ...             ...     ...
# 15055              40              37       0
# 15056              36              37       0
# 15057              50              37       0
# 15058              40              37       0
# 15059              60              37       1
#
# [15060 rows x 15 columns]

# %% [markdown]
# 二、正規化與資料結構整理

# %%
train_mean=train_data.mean(axis=0)

# %%
train_std=train_data.std(axis=0)

# %%
test_mean=test_data.mean(axis=0)

# %%
test_std=test_data.std(axis=0)

# %%
train_data-=train_mean
train_data/=train_std
train_data
# Out:
#             age  workclass    fnlwgt  education  education-num  \
# 0      0.042795   2.935952 -1.062704  -0.349859       1.128900
# 1      0.880274   1.887651 -1.007855  -0.349859       1.128900
# 2     -0.033339  -0.208951  0.244689   0.174760      -0.439731
# 3      1.108677  -0.208951  0.425233  -2.448334      -1.224046
# 4     -0.794684  -0.208951  1.406635  -0.349859       1.128900
# ...         ...        ...       ...        ...            ...
# 30157 -0.870818  -0.208951  0.638961  -0.874478       0.736742
# 30158  0.118929  -0.208951 -0.335247   0.174760      -0.439731
# 30159  1.489349  -0.208951 -0.358569   0.174760      -0.439731
# 15057       -0.395450    0.748973     -0.881961  0.382218  0.695809
# 15058       -1.724057   -1.489770      1.006074 -3.242591  0.695809
# 15059       -0.395450   -0.743522     -0.881961  0.382218  0.695809
#
#        capital-gain  capital-loss  hours-per-week  native-country    salary
# 0         -0.145434     -0.219162       -0.078886        0.260572 -0.570686
# 1         -0.145434     -0.219162        0.750106        0.260572 -0.570686
# 2         -0.145434     -0.219162       -0.078886        0.260572  1.752160
# 3          0.852596     -0.219162       -0.078886        0.260572  1.752160
# 4         -0.145434     -0.219162       -0.907879        0.260572 -0.570686
# ...             ...           ...             ...             ...       ...
# 15055     -0.145434     -0.219162       -0.078886        0.260572 -0.570686
# 15056     -0.145434     -0.219162       -0.410484        0.260572 -0.570686
# 15057     -0.145434     -0.219162        0.750106        0.260572 -0.570686
# 15058      0.562715     -0.219162       -0.078886        0.260572 -0.570686
# 15059     -0.145434     -0.219162        1.579099        0.260572  1.752160
#
# [15060 rows x 15 columns]

# %%
train_predict=train_data.drop(columns=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship'
                      ,'race','sex','capital-gain','capital-loss','native-country','salary'],axis=1)
train_predict
# Out:
#        hours-per-week
# 0           -0.077733
# 1           -2.331492
# 2           -0.077733
# 3           -0.077733
# 4           -0.077733
# ...               ...
# 30157       -0.244678
# 30158       -0.077733
# 30159       -0.077733
# 30160       -1.747184
# 30161       -0.077733
#
# [30162 rows x 1 columns]

# %%
test_predict=test_data.drop(columns=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship'
                      ,'race','sex','capital-gain','capital-loss','native-country','salary'],axis=1)
test_predict
# Out:
#        hours-per-week
# 0           -0.078886
# 1            0.750106
# 2           -0.078886
# 3           -0.078886
# 4           -0.907879
# ...               ...
# 15055       -0.078886
# 15056       -0.410484
# 15057        0.750106
# 15058       -0.078886
# 15059        1.579099
#
# [15060 rows x 1 columns]

# %% [markdown]
# 三、建立前饋神經網路模型

# %%
model1=Sequential()
model1.add(Dense(10,activation='relu',input_shape=(train_data.shape[1],)))
model1.add(Dense(10,activation='relu'))
model1.add(Dense(1,activation='sigmoid'))
model1.compile(loss="mse", optimizer="adam",metrics=["mae"])

# %%
model2=Sequential()
model2.add(Dense(10,activation='relu',input_shape=(train_data.shape[1],)))
model2.add(Dense(10,activation='relu'))
model2.add(Dense(1,activation='sigmoid'))
model2.compile(loss="mse", optimizer="rmsprop",metrics=["mape"])

# %%
model3=Sequential()
model3.add(Dense(10,activation='relu',input_shape=(train_data.shape[1],)))
model3.add(Dense(10,activation='relu'))
model3.add(Dense(1,activation='sigmoid'))
model3.compile(loss="mse", optimizer="adam",metrics=["mse"])

# %% [markdown]
# 四、資料匯入模型訓練

# %%
model1.fit(train_data,train_predict,epochs=20,batch_size=20)
# Out:
# Epoch 1/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.7252 - mae: 0.5247
# Epoch 2/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6342 - mae: 0.4387
# Epoch 3/10
# 1509/1509 [==============================] - 1s 960us/step - loss: 0.6326 - mae: 0.4337
# Epoch 4/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6318 - mae: 0.4303
# Epoch 5/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6307 - mae: 0.4239
# Epoch 6/10
# 1509/1509 [==============================] - 1s 903us/step - loss: 0.6301 - mae: 0.4193
# Epoch 7/10
# 1509/1509 [==============================] - 1s 894us/step - loss: 0.6298 - mae: 0.4174
# Epoch 8/10
# 1509/1509 [==============================] - 1s 873us/step - loss: 0.6295 - mae: 0.4152
# Epoch 9/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6293 - mae: 0.4138
# Epoch 10/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6292 - mae: 0.4134

# %%
model2.fit(train_data,train_predict,epochs=20,batch_size=20)
# Out:
# Epoch 1/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.7170 - mape: 137.0517
# Epoch 2/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6326 - mape: 83.2737
# Epoch 3/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6304 - mape: 77.8117
# Epoch 4/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6299 - mape: 76.1354
# Epoch 5/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6296 - mape: 75.5452
# Epoch 6/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6293 - mape: 75.2363
# Epoch 7/10
# 1509/1509 [==============================] - 1s 944us/step - loss: 0.6292 - mape: 75.1137
# Epoch 8/10
# 1509/1509 [==============================] - 1s 919us/step - loss: 0.6292 - mape: 74.9711
# Epoch 9/10
# 1509/1509 [==============================] - 1s 916us/step - loss: 0.6292 - mape: 74.8743
# Epoch 10/10
# 1509/1509 [==============================] - 1s 991us/step - loss: 0.6292 - mape: 74.7966

# %%
model3.fit(train_data,train_predict,epochs=20,batch_size=20)
# Out:
# Epoch 1/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.7071 - mse: 0.7071
# Epoch 2/10
# 1509/1509 [==============================] - 1s 917us/step - loss: 0.6343 - mse: 0.6343
# Epoch 3/10
# 1509/1509 [==============================] - 1s 866us/step - loss: 0.6324 - mse: 0.6324
# Epoch 4/10
# 1509/1509 [==============================] - 1s 889us/step - loss: 0.6312 - mse: 0.6312
# Epoch 5/10
# 1509/1509 [==============================] - 1s 857us/step - loss: 0.6301 - mse: 0.6301
# Epoch 6/10
# 1509/1509 [==============================] - 1s 992us/step - loss: 0.6295 - mse: 0.6295
# Epoch 7/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6292 - mse: 0.6292
# Epoch 8/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6291 - mse: 0.6291
# Epoch 9/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6290 - mse: 0.6290
# Epoch 10/10
# 1509/1509 [==============================] - 2s 1ms/step - loss: 0.6290 - mse: 0.6290

# %% [markdown]
# 五、績效評估

# %%
loss,mae_score= model1.evaluate(test_data,test_predict)         
print("lose= {:.2f}".format(loss))
print("mae= {:.2f}".format(mae_score))
# Out:
# 471/471 [==============================] - 1s 948us/step - loss: 0.6299 - mae: 0.4135
# lose= 0.63
# mae= 0.41

# %%
loss,mape_score= model2.evaluate(test_data,test_predict)         
print("lose= {:.2f}".format(loss))
print("mape= {:.2f}".format(mape_score))
# Out:
# 471/471 [==============================] - 0s 885us/step - loss: 0.6298 - mape: 74.9659
# lose= 0.63
# mape= 74.97

# %%
loss,mse_score= model3.evaluate(test_data,test_predict)         
print("lose= {:.2f}".format(loss))
print("mse= {:.2f}".format(mse_score))
# Out:
# 471/471 [==============================] - 1s 1ms/step - loss: 0.6296 - mse: 0.6296
# lose= 0.63
# mse= 0.63
